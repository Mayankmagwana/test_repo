# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import TfidfVectorizer
import random
import string

# %%
file = open("nickhampton.txt",'r')

# %%
str = file.read()

# %%
documents = str.split(' ')

# %%
documents
# Out:
# ['20%2',
#  'increase',
#  'in',
#  'Group',
#  'adjusted',
#  'PBT\nwith',
#  'good',
#  'performance',
#  'and',
#  'increased\nmargins',
#  'in',
#  'both',
#  'business',
#  'divisions\nâ€¢',
#  '5%2\n',
#  'increase',
#  'in',
#  'Speciality',
#  'Food\nIngredients',
#  'adjusted',
#  'operating',
#  'profit\nto',
#  'Â£181m:\nâ€“',
#  '8%2\n',
#  'profit',
#  'growth',
#  'in',
#  'core',
#  'business,\ndespite',
#  'North',
#  'America',
#  'volume\ngrowth',
#  'remaining',
#  'challenging\nâ€“',
#  'Â£30m',
#  'increase',
#  'in',
#  'SPLENDAÂ®\nSucralose',
#  'profit',
#  'following',
#  'actions\ntaken',
#  'to',
#  'refocus',
#  'the',
#  'business\nâ€“',
#  'Â£19m',
#  'decrease',
#  'in',
#  'Food',
#  'Systems\nprofit',
#  'with',
#  'significant',
#  'decline\nin',
#  'Europe\nâ€¢',
#  '22%',
#  'increase',
#  'in',
#  'sales',
#  'from',
#  'New\nProducts',
#  'to',
#  'US$105m\nâ€¢',
#  '32%2\n',
#  'increase',
#  'in',
#  'Bulk',
#  'Ingredients\nadjusted',
# ...

# %%
stops = set(stopwords.words('english'))
punctuations = list(string.punctuation)
stops.update(punctuations)

output_words = []
for word in documents:
    if word.lower() not in stops:
        output_words.append(word.lower())

# %%
output_words[426]
# Out:
# 'rate'

# %%
print(pos_tag('')[0][1])
lemmatizer.lemmatize('\nby', wordnet.NOUN)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-b6c283c63a8b> in <module>
# ----> 1 print(pos_tag('')[0][1])
#       2 lemmatizer.lemmatize('\nby', wordnet.NOUN)
#
# IndexError: list index out of range

# %%
lemmatizer = WordNetLemmatizer()

def get_simple_pos(tag):
    
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

count = 0
clean_words = []
for word in output_words:
    pos = pos_tag(word)
    if word != '':
        clean_word = lemmatizer.lemmatize(word, pos = get_simple_pos(pos[0][1]))
    clean_words.append(clean_word)

# %%
len(clean_words)
# Out:
# 2954

# %%
text_documents = [" ".join(word) for word in clean_words]

# %%
text_documents[0]
# Out:
# 'm u c h'

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vec = CountVectorizer(max_features = 300)

# %%
features = count_vec.fit_transform(clean_words)

# %%
count_vec.get_feature_names()
# Out:
# ['19',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2030',
#  '4g',
#  '50',
#  'ability',
#  'able',
#  'accelerate',
#  'achieved',
#  'acquisition',
#  'across',
#  'agility',
#  'already',
#  'also',
#  'ambition',
#  'ambitious',
#  'an',
#  'and',
#  'approach',
#  'area',
#  'around',
#  'as',
#  'at',
#  'attractive',
#  'back',
#  'based',
#  'beauty',
#  'become',
#  'becoming',
#  'been',
#  'being',
#  'belief',
#  'believe',
#  'better',
#  'big',
#  'billion',
#  'brand',
#  'brands',
#  'build',
#  'business',
#  'by',
#  'carbon',
#  'care',
#  'cash',
#  'chain',
#  'challenge',
#  'challenges',
#  'change',
#  'changing',
#  'cleaning',
#  'climate',
#  'commitment',
#  'company',
#  'compass',
#  'competitive',
#  'conditions',
#  'confident',
#  'connect',
#  'consistent',
#  'consumer',
#  'consumers',
#  'continue',
#  'continuing',
#  'covid',
#  'creation',
#  'crisis',
#  'deep',
#  'deliver',
#  'delivered',
#  'delivering',
#  'demand',
#  'despite',
# ...

# %%
dict = count_vec.vocabulary_ 
sort_orders = sorted(dict.items(),key = lambda x: x[1],reverse = True)

# %%
sort_orders
# Out:
# [('year', 299),
#  ('would', 298),
#  ('world', 297),
#  ('working', 296),
#  ('work', 295),
#  ('wonderful', 294),
#  ('woman', 293),
#  ('with', 292),
#  ('wish', 291),
#  ('will', 290),
#  ('while', 289),
#  ('which', 288),
#  ('what', 287),
#  ('well', 286),
#  ('we', 285),
#  ('ways', 284),
#  ('way', 283),
#  ('was', 282),
#  ('want', 281),
#  ('volatile', 280),
#  ('very', 279),
#  ('value', 278),
#  ('use', 277),
#  ('us', 276),
#  ('up', 275),
#  ('unileverâ', 274),
#  ('unilever', 273),
#  ('underway', 272),
#  ('underlying', 271),
#  ('under', 270),
#  ('two', 269),
#  ('turnover', 268),
#  ('trend', 267),
#  ('together', 266),
#  ('to', 265),
#  ('time', 264),
#  ('through', 263),
#  ('three', 262),
#  ('those', 261),
#  ('this', 260),
#  ('therefore', 259),
#  ('the', 258),
#  ('that', 257),
#  ('thank', 256),
#  ('than', 255),
#  ('term', 254),
#  ('technology', 253),
#  ('take', 252),
#  ('sustainable', 251),
#  ('sustainability', 250),
#  ('sure', 249),
# ...
